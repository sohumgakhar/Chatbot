# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import random
import os
os.chdir('../Chatbot/')
lemmatizer = WordNetLemmatizer()
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = '../Chatbot/intents.json'
with open(data_file) as f:
    intents = json.loads(f.read())

# Perform Tokenization
    
for intent in intents['intentions']:
    for pattern in intent['patterns']:
        
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #adding documents in the corpus
        documents.append((w, intent['tag']))
        # adding to classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
#print (len(documents), " = number of documents")
# classes = intents
#print (len(classes), "classes = ", classes)
# words = all words, vocabulary
#print (len(words), "unique lemmatized words = ", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# Lemmatization , lowering each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
#print (len(documents), "number of documents")
#print (len(classes), "classes = ", classes)
#print (len(words), "unique words = ", words)

#Store as a pickle file
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# Create Training and Testing Data


training = []
# Empty array for output
output_empty = [0]*len(classes)
# training set, bag of words for each sentence
for doc in documents:
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
for w in words:
    bag.append(1) if w in patter_words else bag.append(0)
    # output ='0' for each tag and '1' for current tag (for each pattern)
output_row = list(output_empty)
output_row[classes.index(doc[1])] = 1
training.append([bag, output_row])
# shuffle features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
x_train = list(training[:,0])
y_train = list(training[:,1])

# Create a model
model = Sequential()
model.add(Dense(64,input_shape = (len(x_train[0]),),activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(len(y_train[0]),activation = 'softmax'))
          
model.compile(optimizer = 'adadelta',loss = 'categorical_crossentropy',metrics = ['accuracy'])
hist = model.fit(np.array(x_train),np.array(y_train),batch_size = 5,epochs = 100)
model.save('Model_sophia.h5',hist)
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 85/85 [==============================] - 1s 15ms/step - loss: 1.2404 - accuracy: 0.8588
# Epoch 2/100
# 85/85 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 1.0000
# Epoch 3/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 4/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 5/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 6/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 7/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 8/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 9/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 10/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 11/100
# 85/85 [==============================] - 0s 2ms/step - loss: 5.5714e-04 - accuracy: 1.0000
# Epoch 12/100
# 85/85 [==============================] - 0s 2ms/step - loss: 3.9648e-04 - accuracy: 1.0000
# Epoch 13/100
# 85/85 [==============================] - 0s 2ms/step - loss: 3.2888e-04 - accuracy: 1.0000
# Epoch 14/100
# 85/85 [==============================] - 0s 2ms/step - loss: 2.2979e-04 - accuracy: 1.0000
# Epoch 15/100
# 85/85 [==============================] - 0s 2ms/step - loss: 2.7613e-04 - accuracy: 1.0000
# Epoch 16/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0819e-04 - accuracy: 1.0000
# Epoch 17/100
# 85/85 [==============================] - 0s 2ms/step - loss: 6.9064e-05 - accuracy: 1.0000
# Epoch 18/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2126e-04 - accuracy: 1.0000
# Epoch 19/100
# 85/85 [==============================] - 0s 2ms/step - loss: 6.9221e-05 - accuracy: 1.0000
# Epoch 20/100
# 85/85 [==============================] - 0s 2ms/step - loss: 6.1006e-05 - accuracy: 1.0000
# Epoch 21/100
# 85/85 [==============================] - 0s 2ms/step - loss: 8.6431e-05 - accuracy: 1.0000
# Epoch 22/100
# 85/85 [==============================] - 0s 2ms/step - loss: 8.1498e-05 - accuracy: 1.0000
# Epoch 23/100
# 85/85 [==============================] - 0s 2ms/step - loss: 5.1215e-05 - accuracy: 1.0000
# Epoch 24/100
# 85/85 [==============================] - 0s 2ms/step - loss: 6.8180e-05 - accuracy: 1.0000
# Epoch 25/100
# 85/85 [==============================] - 0s 3ms/step - loss: 3.3851e-05 - accuracy: 1.0000
# Epoch 26/100
# 85/85 [==============================] - 0s 2ms/step - loss: 5.3612e-05 - accuracy: 1.0000
# Epoch 27/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.6653e-05 - accuracy: 1.0000
# Epoch 28/100
# 85/85 [==============================] - 0s 2ms/step - loss: 3.7812e-05 - accuracy: 1.0000
# Epoch 29/100
# 85/85 [==============================] - 0s 2ms/step - loss: 3.1379e-05 - accuracy: 1.0000
# Epoch 30/100
# 85/85 [==============================] - 0s 2ms/step - loss: 4.7978e-05 - accuracy: 1.0000
# Epoch 31/100
# 85/85 [==============================] - ETA: 0s - loss: 1.7372e-05 - accuracy: 1.00 - 0s 2ms/step - loss: 1.4349e-05 - accuracy: 1.0000
# Epoch 32/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3846e-05 - accuracy: 1.0000
# Epoch 33/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.5514e-05 - accuracy: 1.0000
# Epoch 34/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.4494e-05 - accuracy: 1.0000
# Epoch 35/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.6458e-05 - accuracy: 1.0000
# Epoch 36/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.8465e-05 - accuracy: 1.0000
# Epoch 37/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0071e-05 - accuracy: 1.0000
# Epoch 38/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3963e-05 - accuracy: 1.0000
# Epoch 39/100
# 85/85 [==============================] - 0s 2ms/step - loss: 2.2548e-05 - accuracy: 1.0000
# Epoch 40/100
# 85/85 [==============================] - 0s 2ms/step - loss: 2.6003e-05 - accuracy: 1.0000
# Epoch 41/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.5769e-05 - accuracy: 1.0000
# Epoch 42/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3640e-05 - accuracy: 1.0000
# Epoch 43/100
# 85/85 [==============================] - 0s 2ms/step - loss: 6.2984e-06 - accuracy: 1.0000
# Epoch 44/100
# 85/85 [==============================] - 0s 3ms/step - loss: 1.8454e-05 - accuracy: 1.0000
# Epoch 45/100
# 85/85 [==============================] - 0s 2ms/step - loss: 9.3471e-06 - accuracy: 1.0000
# Epoch 46/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.9384e-05 - accuracy: 1.0000
# Epoch 47/100
# 85/85 [==============================] - 0s 2ms/step - loss: 1.9146e-05 - accuracy: 1.0000
# Epoch 48/100
# 70/85 [=======================>......] - ETA: 0s - loss: 5.9143e-06 - accuracy: 1.0000
